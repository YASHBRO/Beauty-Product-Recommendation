# %%
from data_processing import data_cleaning
from models import linear_svc, naive_bayes
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yashj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import os

review_path = os.path.join("..", "data", "All_Beauty.jsonl")
cleaned_review_path = os.path.join("..", "data", "cleaned_All_Beauty.jsonl")
meta_review_path = os.path.join("..", "data", "meta_All_Beauty.jsonl")
cleaned_meta_review_path = os.path.join("..", "data", "cleaned_meta_All_Beauty.jsonl")
merged_data_path = os.path.join("..", "data", "merged_reviews.jsonl")

# %%
# Clean user reviews data
cleaned_reviews = data_cleaning.reviews_clean(
    src_path=review_path,
    dest_path=cleaned_review_path,
)

cleaned_reviews
# Out:
# Column reviewerName not found in the dataset.
# Column reviewText not found in the dataset.
# Column summary not found in the dataset.
# Column reviewText not found in the dataset.
# Column summary not found in the dataset.
#         rating                                      title  \
# 0            5  Such a lovely scent but not overpowering.
# 1            4     Works great but smells a little weird.
# 2            5                                       Yes!
# 3            1                          Synthetic feeling
# 4            5                                         A+
# ...        ...                                        ...
# 694248       4                                 Four Stars
# 694249       1                                     Pretty
# 694250       5                       Great sunless tanner
# 694251       5              The Crown on top is a Ring!!!
# 694252       4                   Good Shampoo/Conditioner
#
# ...

# %%
# Clean meta data
cleaned_meta = data_cleaning.meta_clean(
    src_path=meta_review_path,
    dest_path=cleaned_meta_review_path,
)

cleaned_meta
# Out:
# D:\Projects\beauty_product_recommendation\data_processing\data_cleaning.py:148: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["description"].fillna(
# D:\Projects\beauty_product_recommendation\data_processing\data_cleaning.py:161: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Train Linear SVC model
svc_dest_path = os.path.join("..", "models", "pickle_files", "svc")

linear_svc_vectors, linear_svc_model = linear_svc.train(
    df_path=cleaned_review_path,
    pickle_storage_path=svc_dest_path
)
# Out:
# Loading Data ...
# Generating Sentiment ...
# Sampling data ...
# Text Processing Pipeline ...
# Vectorizing ...
# Parameter tuning ...
# Best C = 0.1 | Accuracy = 0.6847502820223568
# Testing Final model...
# This product was okish >> -1
# I have mixed feelings about this product. >> 0
# it is not upto mark >> -1
# great >> 1
# kinda okay >> 0
# Storing vectorizer and model in pickle file ...
# Storing model in pickle file ...
# Done.

# %%
# Train Naive Bayes model
nb_dest_path = os.path.join("..", "models", "pickle_files", "nb")

nb_vectors, nb_tfidf, nb_model = naive_bayes.train(
    df_path=cleaned_review_path, pickle_storage_path=nb_dest_path
)
# Out:
# Loading Data...
# Generating Sentiment...
# Sampling data...
# Text Cleaning ...
# Vectorizing...
# Multinomial Naïve Bayes model Training...
# Accuracy Score : 0.5545383681090587
# Bernoulli Naïve Bayes model Training...
# Accuracy Score : 0.4178706741837826
# Training Multinomial Naïve Bayes model as final model
# Testing Final model...
# classes : [1 2 3 4 5]
# good >> [0.10610523 0.02311464 0.42061118 0.02074648 0.42942246]
# okay >> [0.0355599  0.02524512 0.90338533 0.00730859 0.02850105]
# good enough >> [0.09224827 0.0251605  0.73792898 0.00834075 0.1363215 ]
# kind good >> [0.15105222 0.05588306 0.49659444 0.02530734 0.27116294]
# bad >> [0.37071093 0.03804207 0.50552709 0.00970726 0.07601265]
# Making Pickle files...
# Storing CountVectorizer
# Storing TfidfTransformer
# Storing Final Model
# Done.
